# %%
from ultralytics import YOLO

model = YOLO("models/POSM_YOLO11X.pt")

for idx, name in sorted(model.names.items()):
    print(f"{idx}: {name}")
# Out:
# 0: dove_conditioner_sachet_hanger_jan26
# 1: gal_relaunch_bunting_jan26
# 2: gal_relaunch_poster_jan26
# 3: gal_relaunch_shelf_strip_feb26
# 4: gal_shelftalker_bottom
# 5: gal_shelftalker_left
# 6: gal_shelftalker_right
# 7: gal_shelftalker_top
# 8: haircare_shelftalker_bottom
# 9: haircare_shelftalker_left
# 10: haircare_shelftalker_right
# 11: haircare_shelftalker_top
# 12: knorr_soup_large_sticker_feb26
# 13: lifebuoy_bar_wc_poster_nov
# 14: pepsodent_germicheck_poster_feb26
# 15: ponds_localisation_poster_feb26
# 16: ponds_localisation_sticker_feb26
# 17: ponds_shelftalker_bottom
# 18: ponds_shelftalker_left
# 19: ponds_shelftalker_right
# 20: ponds_shelftalker_top
# 21: sunsilk_triple_sachet_poster_jan26
# 22: wheel_poster_dec25
# 23: wheel_sunshade_dec25

# %%
from ultralytics import YOLO

model = YOLO("models/Shelftalker.pt")

for idx, name in sorted(model.names.items()):
    print(f"{idx}: {name}")
# Out:
# 0: da_gal_st_bottom
# 1: da_gal_st_left
# 2: da_gal_st_right
# 3: da_gal_st_top
# 4: da_hair_care_st_bottom
# 5: da_hair_care_st_left
# 6: da_hair_care_st_right
# 7: da_hair_care_st_top
# 8: da_lotion_st_bottom
# 9: da_lotion_st_left
# 10: da_lotion_st_right
# 11: da_lotion_st_top
# 12: da_lux_st_bottom
# 13: da_lux_st_left
# 14: da_lux_st_right
# 15: da_lux_st_top
# 16: da_ns_st_1_left
# 17: da_ns_st_1_right
# 18: da_ns_st_2_left
# 19: da_ns_st_2_right
# 20: da_ns_st_below_bottom
# 21: da_ns_st_bottom
# 22: da_ns_st_jr_bottom
# 23: da_ns_st_jr_left
# 24: da_ns_st_jr_right
# 25: da_ns_st_jr_top
# 26: da_ns_st_top
# 27: da_ponds_st_bottom
# 28: da_ponds_st_left
# 29: da_ponds_st_right
# 30: da_ponds_st_top
# 31: da_surfexcel_st_bottom
# 32: da_surfexcel_st_left
# 33: da_surfexcel_st_right
# 34: da_surfexcel_st_top
# 35: da_toothpaste_st_bottom
# 36: da_toothpaste_st_left
# 37: da_toothpaste_st_right
# 38: da_toothpaste_st_top
# 39: da_vim_st_bottom
# 40: da_vim_st_left
# ...

# %%
from ultralytics import YOLO

model = YOLO("models/Shelftalker.pt")

results = model.predict("/home/mkultra/Desktop/Skin_Care_20260301_115822_0535b35b.jpg")
# Out:
# image 1/1 /home/mkultra/Desktop/Skin_Care_20260301_115822_0535b35b.jpg: 480x640 1 da_gal_st_right, 1 da_hair_care_st_bottom, 1 da_lux_st_left, 1 da_ponds_st_bottom, 1 da_ponds_st_left, 1 da_ponds_st_right, 78.9ms
# Speed: 5.3ms preprocess, 78.9ms inference, 23.0ms postprocess per image at shape (1, 3, 480, 640)
